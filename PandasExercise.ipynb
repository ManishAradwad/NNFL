# %% [markdown]
# <a href="https://colab.research.google.com/github/ManishAradwad/NNFL/blob/master/PandasExercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pd
data=pd.read_csv('NNFL DATASET.csv')

# %%
data.head()
# Out:
#                         Timestamp  Height in cm  ...   Sex       Branch
# 0  2020/01/14 9:57:11 AM GMT+5:30         175.0  ...  Male  Electronics
# 1  2020/01/14 9:57:19 AM GMT+5:30         175.0  ...  Male  Electronics
# 2  2020/01/14 9:57:31 AM GMT+5:30         176.0  ...  Male  Electronics
# 3  2020/01/14 9:58:39 AM GMT+5:30         168.0  ...  Male  Electronics
# 4  2020/01/14 9:58:58 AM GMT+5:30         172.0  ...  Male  Electronics
#
# [5 rows x 6 columns]

# %%
data.describe()
# Out:
#        Height in cm  Weight in kg   Age in years
# count     60.000000      60.000000     60.000000
# mean     169.072333      60.435000     20.000000
# std        9.878744      11.985907      0.487122
# min      148.000000      38.000000     19.000000
# 25%      162.500000      50.000000     20.000000
# 50%      170.500000      59.500000     20.000000
# 75%      176.000000      68.250000     20.000000
# max      186.000000      93.000000     21.000000

# %%
data.tail()
# Out:
#                           Timestamp  Height in cm  ...     Sex       Branch
# 55   2020/01/16 8:27:28 PM GMT+5:30         160.0  ...    Male  Electronics
# 56   2020/01/17 8:37:11 PM GMT+5:30         180.0  ...    Male  Electronics
# 57  2020/01/20 12:29:01 AM GMT+5:30         183.0  ...    Male  Electronics
# 58  2020/01/20 12:59:08 PM GMT+5:30         165.0  ...  Female  Electronics
# 59  2020/01/21 11:40:52 PM GMT+5:30         175.0  ...    Male  Electronics
#
# [5 rows x 6 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 6 columns):
# Timestamp        60 non-null object
# Height in cm     60 non-null float64
# Weight in kg     60 non-null float64
# Age in years     60 non-null int64
# Sex              60 non-null object
# Branch           60 non-null object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 2.9+ KB

# %%
s=data["Height in cm"]

# %%
print(s)
# Out:
# 0     175.00
# 1     175.00
# 2     176.00
# 3     168.00
# 4     172.00
# 5     171.00
# 6     175.00
# 7     180.00
# 8     186.00
# 9     180.00
# 10    175.00
# 11    150.00
# 12    163.00
# 13    150.00
# 14    154.00
# 15    148.00
# 16    175.00
# 17    180.00
# 18    161.00
# 19    167.64
# 20    160.00
# 21    167.00
# 22    175.00
# 23    173.00
# 24    175.00
# 25    171.00
# 26    167.00
# 27    176.00
# 28    150.00
# 29    158.00
# 30    170.00
# 31    166.00
# 32    170.00
# 33    180.00
# 34    163.00
# 35    180.00
# 36    177.80
# 37    180.00
# 38    180.00
# 39    168.00
# 40    180.00
# 41    152.40
# 42    160.00
# 43    165.00
# 44    175.00
# 45    160.00
# 46    157.50
# 47    165.00
# 48    160.00
# 49    150.00
# 50    180.00
# 51    167.00
# 52    185.00
# 53    171.00
# 54    165.00
# 55    160.00
# 56    180.00
# 57    183.00
# 58    165.00
# 59    175.00
# Name: Height in cm, dtype: float64

# %%
data.sort_values("Height in cm")
# Out:
#                           Timestamp  Height in cm  ...     Sex       Branch
# 15   2020/01/14 3:59:15 PM GMT+5:30        148.00  ...  Female  Electronics
# 28  2020/01/15 11:00:39 PM GMT+5:30        150.00  ...  Female  Electronics
# 49  2020/01/16 10:28:23 AM GMT+5:30        150.00  ...  Female  Electronics
# 13   2020/01/14 3:25:21 PM GMT+5:30        150.00  ...  Female  Electronics
# 11  2020/01/14 12:38:45 PM GMT+5:30        150.00  ...  Female  Electronics
# 41  2020/01/16 10:22:41 AM GMT+5:30        152.40  ...  Female  Electronics
# 14   2020/01/14 3:57:43 PM GMT+5:30        154.00  ...  Female  Electronics
# 46  2020/01/16 10:23:28 AM GMT+5:30        157.50  ...  Female  Electronics
# 29  2020/01/16 10:19:22 AM GMT+5:30        158.00  ...  Female  Electronics
# 42  2020/01/16 10:22:45 AM GMT+5:30        160.00  ...    Male  Electronics
# 20  2020/01/15 12:44:32 AM GMT+5:30        160.00  ...  Female  Electronics
# ...

# %%
data.sort_values(['Height in cm',"Weight in kg "])
# Out:
#                           Timestamp  Height in cm  ...     Sex       Branch
# 15   2020/01/14 3:59:15 PM GMT+5:30        148.00  ...  Female  Electronics
# 13   2020/01/14 3:25:21 PM GMT+5:30        150.00  ...  Female  Electronics
# 11  2020/01/14 12:38:45 PM GMT+5:30        150.00  ...  Female  Electronics
# 28  2020/01/15 11:00:39 PM GMT+5:30        150.00  ...  Female  Electronics
# 49  2020/01/16 10:28:23 AM GMT+5:30        150.00  ...  Female  Electronics
# 41  2020/01/16 10:22:41 AM GMT+5:30        152.40  ...  Female  Electronics
# 14   2020/01/14 3:57:43 PM GMT+5:30        154.00  ...  Female  Electronics
# 46  2020/01/16 10:23:28 AM GMT+5:30        157.50  ...  Female  Electronics
# 29  2020/01/16 10:19:22 AM GMT+5:30        158.00  ...  Female  Electronics
# 20  2020/01/15 12:44:32 AM GMT+5:30        160.00  ...  Female  Electronics
# 55   2020/01/16 8:27:28 PM GMT+5:30        160.00  ...    Male  Electronics
# ...

# %%
data.sort_index()
# Out:
#                           Timestamp  Height in cm  ...     Sex       Branch
# 0    2020/01/14 9:57:11 AM GMT+5:30        175.00  ...    Male  Electronics
# 1    2020/01/14 9:57:19 AM GMT+5:30        175.00  ...    Male  Electronics
# 2    2020/01/14 9:57:31 AM GMT+5:30        176.00  ...    Male  Electronics
# 3    2020/01/14 9:58:39 AM GMT+5:30        168.00  ...    Male  Electronics
# 4    2020/01/14 9:58:58 AM GMT+5:30        172.00  ...    Male  Electronics
# 5   2020/01/14 10:00:28 AM GMT+5:30        171.00  ...    Male  Electronics
# 6   2020/01/14 10:01:02 AM GMT+5:30        175.00  ...    Male  Electronics
# 7   2020/01/14 10:01:16 AM GMT+5:30        180.00  ...    Male  Electronics
# 8   2020/01/14 10:02:55 AM GMT+5:30        186.00  ...    Male  Electronics
# 9   2020/01/14 11:10:28 AM GMT+5:30        180.00  ...    Male  Electronics
# 10  2020/01/14 11:33:36 AM GMT+5:30        175.00  ...    Male  Electronics
# ...

# %%
data.sort_values('Height in cm',ascending=True,inplace=True)

# %%
data
# Out:
#                           Timestamp  Height in cm  ...     Sex       Branch
# 15   2020/01/14 3:59:15 PM GMT+5:30        148.00  ...  Female  Electronics
# 28  2020/01/15 11:00:39 PM GMT+5:30        150.00  ...  Female  Electronics
# 49  2020/01/16 10:28:23 AM GMT+5:30        150.00  ...  Female  Electronics
# 13   2020/01/14 3:25:21 PM GMT+5:30        150.00  ...  Female  Electronics
# 11  2020/01/14 12:38:45 PM GMT+5:30        150.00  ...  Female  Electronics
# 41  2020/01/16 10:22:41 AM GMT+5:30        152.40  ...  Female  Electronics
# 14   2020/01/14 3:57:43 PM GMT+5:30        154.00  ...  Female  Electronics
# 46  2020/01/16 10:23:28 AM GMT+5:30        157.50  ...  Female  Electronics
# 29  2020/01/16 10:19:22 AM GMT+5:30        158.00  ...  Female  Electronics
# 42  2020/01/16 10:22:45 AM GMT+5:30        160.00  ...    Male  Electronics
# 20  2020/01/15 12:44:32 AM GMT+5:30        160.00  ...  Female  Electronics
# ...

# %%
data.sort_values('Height in cm',ascending=False,inplace=True)

# %%
data
# Out:
#                           Timestamp  Height in cm  ...     Sex       Branch
# 8   2020/01/14 10:02:55 AM GMT+5:30        186.00  ...    Male  Electronics
# 52  2020/01/16 10:32:25 AM GMT+5:30        185.00  ...    Male  Electronics
# 57  2020/01/20 12:29:01 AM GMT+5:30        183.00  ...    Male  Electronics
# 56   2020/01/17 8:37:11 PM GMT+5:30        180.00  ...    Male  Electronics
# 9   2020/01/14 11:10:28 AM GMT+5:30        180.00  ...    Male  Electronics
# 38  2020/01/16 10:22:00 AM GMT+5:30        180.00  ...    Male  Electronics
# 35  2020/01/16 10:21:03 AM GMT+5:30        180.00  ...    Male  Electronics
# 40  2020/01/16 10:22:15 AM GMT+5:30        180.00  ...    Male  Electronics
# 33  2020/01/16 10:20:14 AM GMT+5:30        180.00  ...    Male  Electronics
# 17   2020/01/14 8:41:22 PM GMT+5:30        180.00  ...    Male  Electronics
# 37  2020/01/16 10:21:54 AM GMT+5:30        180.00  ...    Male  Electronics
# ...

# %%
data['Height in cm']=data['Height in cm'].astype('int')

# %%
data
# Out:
#                           Timestamp  Height in cm  ...     Sex       Branch
# 8   2020/01/14 10:02:55 AM GMT+5:30           186  ...    Male  Electronics
# 52  2020/01/16 10:32:25 AM GMT+5:30           185  ...    Male  Electronics
# 57  2020/01/20 12:29:01 AM GMT+5:30           183  ...    Male  Electronics
# 56   2020/01/17 8:37:11 PM GMT+5:30           180  ...    Male  Electronics
# 9   2020/01/14 11:10:28 AM GMT+5:30           180  ...    Male  Electronics
# 38  2020/01/16 10:22:00 AM GMT+5:30           180  ...    Male  Electronics
# 35  2020/01/16 10:21:03 AM GMT+5:30           180  ...    Male  Electronics
# 40  2020/01/16 10:22:15 AM GMT+5:30           180  ...    Male  Electronics
# 33  2020/01/16 10:20:14 AM GMT+5:30           180  ...    Male  Electronics
# 17   2020/01/14 8:41:22 PM GMT+5:30           180  ...    Male  Electronics
# 37  2020/01/16 10:21:54 AM GMT+5:30           180  ...    Male  Electronics
# ...

# %%
data['ones']=1

# %%
data
# Out:
#                           Timestamp  Height in cm  ...       Branch  ones
# 8   2020/01/14 10:02:55 AM GMT+5:30           186  ...  Electronics     1
# 52  2020/01/16 10:32:25 AM GMT+5:30           185  ...  Electronics     1
# 57  2020/01/20 12:29:01 AM GMT+5:30           183  ...  Electronics     1
# 56   2020/01/17 8:37:11 PM GMT+5:30           180  ...  Electronics     1
# 9   2020/01/14 11:10:28 AM GMT+5:30           180  ...  Electronics     1
# 38  2020/01/16 10:22:00 AM GMT+5:30           180  ...  Electronics     1
# 35  2020/01/16 10:21:03 AM GMT+5:30           180  ...  Electronics     1
# 40  2020/01/16 10:22:15 AM GMT+5:30           180  ...  Electronics     1
# 33  2020/01/16 10:20:14 AM GMT+5:30           180  ...  Electronics     1
# 17   2020/01/14 8:41:22 PM GMT+5:30           180  ...  Electronics     1
# 37  2020/01/16 10:21:54 AM GMT+5:30           180  ...  Electronics     1
# 50  2020/01/16 10:30:07 AM GMT+5:30           180  ...  Electronics     1
# ...

# %%
data['Height in cm'].nunique()
# Out:
# 24

# %%
data['Height in cm'].unique()
# Out:
# array([186, 185, 183, 180, 177, 176, 175, 173, 172, 171, 170, 168, 167,
#        166, 165, 163, 161, 160, 158, 157, 154, 152, 150, 148])

# %%
data.shape
# Out:
# (60, 7)
