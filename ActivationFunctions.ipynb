# %% [markdown]
# <a href="https://colab.research.google.com/github/ManishAradwad/NNFL/blob/master/ActivationFunctions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
n=range(-10,10)
y=[]
# Simple Hard Limit
for i in n:
  if i<=0:
    y.append(0)
  else:
    y.append(1)
plt.step(n,y,label="simple Hard Limit")
plt.legend(loc="upper left")
plt.axhspan(0,0,linewidth=2,color='#000000')
plt.axvline(0,0,linewidth=2,color='#000000')

# %%
# Symmetrical Hard Limit
y=[]
for i in n:
  if i<=0:
    y.append(-1)
  else:
    y.append(1)
plt.step(n,y,label="symmetrical Hard Limit")
plt.legend(loc="upper left")
plt.axhspan(0,0,linewidth=2,color='#000000')
plt.axvline(0,0,linewidth=2,color='#000000')

# %%
#Linear
y=[]
for i in n:
  if i<=0:
    y.append(0)
  else:
    y.append(i)
plt.plot(n,y,label="Linear function")
plt.legend(loc="upper left")
plt.axhspan(0,0,linewidth=2,color='#000000')
plt.axvline(0,0,linewidth=2,color='#000000')

# %%
# Saturating Linear
y=[]
for i in n:
  if i<0:
    y.append(0)
  elif -1<=i<=1:
    y.append(i)
  else:
    y.append(1)
plt.plot(n,y,label="Saturating Linear")
plt.legend(loc="upper left")
plt.axhspan(0,0,linewidth=2,color='#000000')
plt.axvline(0,0,linewidth=2,color='#000000')

# %%
#Symmetric Saturating Linear
y=[]
for i in n:
  if i<0:
    y.append(-1)
  elif -1<=i<=1:
    y.append(i)
  else:
    y.append(1)
plt.plot(n,y,label="Symmetric Saturating Linear")
plt.legend(loc="upper left")
plt.axhspan(0,0,linewidth=2,color='#000000')
plt.axvline(0,0,linewidth=2,color='#000000')

# %%
# Log-Sigmoid
import math 
y=[1/(1+math.e**-i) for i in n]
plt.plot(n,y,label="Log-sigmoid")
plt.legend(loc="upper left")
plt.axhspan(0,0,linewidth=2,color='#000000')
plt.axvline(0,0,linewidth=2,color='#000000')

# %%
# Hyperbolic Tangent-Sigmoid 
y=[(math.e**i-math.e**-i)/(math.e**i+math.e**-i) for i in n]
plt.plot(n,y,label="hyperbolic tangent-sigmoid")
plt.legend(loc="upper left")
plt.axhspan(0,0,linewidth=2,color='#000000')
plt.axvline(0,0,linewidth=2,color='#000000')

# %%
#Relu
y=[]
for i in n:
  if i<0:
    y.append(i)
  else:
    y.append(0)
plt.plot(n,y,label="Relu")
plt.legend(loc="upper left")
plt.axhspan(0,0,linewidth=2,color='#000000')
plt.axvline(0,0,linewidth=2,color='#000000')

# %%
#Softmax
import numpy as np
n = np.array(n)
y = np.exp(n)/sum(np.exp(n))
plt.plot(n,y,label="Softmax")
plt.legend(loc="upper left")
plt.axhspan(0,0,linewidth=2,color='#000000')
plt.axvline(0,0,linewidth=2,color='#000000')
